# %%
base_path = r"C:\Users\ASUS\Desktop\Mini Project\Deepfake-video-Detection\ML model\pretrained"

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Model 1
model1 = torch.load(base_path + r"\efficientnet-b0-ffpp-c23.pt", map_location=device,weights_only=False)
model1.eval()

# Model 2 (ViT)
from transformers import ViTForImageClassification, ViTImageProcessor

model2 = ViTForImageClassification.from_pretrained(base_path + r"\vit_deepfake_model")
processor2 = ViTImageProcessor.from_pretrained(base_path + r"\vit_deepfake_model")
model2.to(device)
model2.eval()

# Model 3
model3 = torch.load(base_path + r"\best_model-v3.pt", map_location=device,weights_only=False)
model3.eval()

# Model 4
model4 = torch.load(base_path + r"\model_97_acc_100_frames_FF_data.pt", map_location=device,weights_only=False)
model4.eval()

# Model 5
model5 = torch.load(base_path + r"\custom_trained.pth", map_location=device,weights_only=False)
model5.eval()
# Out:
# Loading weights:   0%|          | 0/200 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 19
#      17 # Model 3
#      18 model3 = torch.load(base_path + r"\best_model-v3.pt", map_location=device,weights_only=False)
# ---> 19 model3.eval()
#      21 # Model 4
#      22 model4 = torch.load(base_path + r"\model_97_acc_100_frames_FF_data.pt", map_location=device,weights_only=False)
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'eval'
